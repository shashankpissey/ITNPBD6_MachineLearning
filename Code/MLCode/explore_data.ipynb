# %%
import pandas as pd
import matplotlib.pyplot as plt

#Read CSV
data = pd.read_csv("data/wallacecommunications.csv")
#Print data insights to check info, null or NaN rows and sample data
print(f"Info: \n {data.info()}")
print(f"null counts:\n {data.isnull().sum()}")
print(f"na counts: \n {data.isna().sum()}")
print(f"sample rows : \n {data.head()}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50662 entries, 0 to 50661
# Data columns (total 20 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         50662 non-null  int64
#  1   town                                       50662 non-null  object
#  2   country                                    50662 non-null  object
#  3   age                                        50662 non-null  int64
#  4   job                                        50662 non-null  object
#  5   married                                    50662 non-null  object
#  6   education                                  50662 non-null  object
#  7   arrears                                    50662 non-null  object
#  8   current_balance                            50662 non-null  float64
#  9   housing                                    50662 non-null  object
#  10  has_tv_package                             50662 non-null  object
#  11  last_contact                               50662 non-null  object
#  12  conn_tr                                    50662 non-null  int64
#  13  last_contact_this_campaign_day             50662 non-null  int64
#  14  last_contact_this_campaign_month           50662 non-null  object
#  15  this_campaign                              50662 non-null  int64
#  16  days_since_last_contact_previous_campaign  50662 non-null  int64
#  17  contacted_during_previous_campaign         50662 non-null  int64
#  18  outcome_previous_campaign                  50662 non-null  object
#  19  new_contract_this_campaign                 50662 non-null  object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 7.7+ MB
# Info:
#  None
# null counts:
#  ID                                           0
# town                                         0
# country                                      0
# age                                          0
# job                                          0
# married                                      0
# education                                    0
# arrears                                      0
# current_balance                              0
# housing                                      0
# has_tv_package                               0
# last_contact                                 0
# conn_tr                                      0
# last_contact_this_campaign_day               0
# last_contact_this_campaign_month             0
# this_campaign                                0
# days_since_last_contact_previous_campaign    0
# contacted_during_previous_campaign           0
# outcome_previous_campaign                    0
# new_contract_this_campaign                   0
# dtype: int64
# na counts:
#  ID                                           0
# town                                         0
# country                                      0
# age                                          0
# job                                          0
# married                                      0
# education                                    0
# arrears                                      0
# current_balance                              0
# housing                                      0
# has_tv_package                               0
# last_contact                                 0
# conn_tr                                      0
# last_contact_this_campaign_day               0
# last_contact_this_campaign_month             0
# this_campaign                                0
# days_since_last_contact_previous_campaign    0
# contacted_during_previous_campaign           0
# outcome_previous_campaign                    0
# new_contract_this_campaign                   0
# dtype: int64
# sample rows :
#           ID           town country  age         job   married  education  \
# 0  32390233        Bristol      UK   39  management   married   tertiary
# 1  41226029       Basildon      UK   53   housemaid   married    primary
# 2  85498057      Blackburn      UK   79     retired  divorced    primary
# 3  76539627         Oldham      UK   43    services    single  secondary
# 4  76290986  Middlesbrough      UK   35  technician    single  secondary
#
#   arrears  current_balance housing has_tv_package last_contact  conn_tr  \
# 0      no            -1.90      no            yes      unknown        4
# 1      no             3.62      no             no     cellular        1
# 2      no            27.87      no             no    telephone        3
# 3      no             5.50     yes             no     cellular        3
# 4      no             3.44      no             no     cellular        2
#
#    last_contact_this_campaign_day last_contact_this_campaign_month  \
# 0                              11                              jun
# 1                              28                              jul
# 2                              13                              jul
# 3                              13                              may
# 4                              27                              aug
#
#    this_campaign  days_since_last_contact_previous_campaign  \
# 0              8                                         -1
# 1              2                                         -1
# 2              1                                        377
# 3              2                                         -1
# 4             16                                         -1
#
#    contacted_during_previous_campaign outcome_previous_campaign  \
# 0                                   0                   unknown
# 1                                   0                   unknown
# 2                                   1                   success
# 3                                   0                   unknown
# 4                                   0                   unknown
#
#   new_contract_this_campaign
# 0                        yes
# 1                        yes
# 2                        yes
# 3                         no
# 4                        yes

# %% [markdown]
# Understanding of data is that:
# 1. There are no null or NaN rows
# 2. ID is a column that is just identifier and has no direct role in prediction
# 3. There are 3 binary columns and 1 target binary column
# 4. curren_balance can be negative

# %%
#Find unique values for each
for data_col in data.columns:
    print(f"{data_col}: {data[data_col].unique()}")
# Out:
# ID: [32390233 41226029 85498057 ... 14476386 63746806 18687856]
# town: ['Bristol' 'Basildon' 'Blackburn' 'Oldham' 'Middlesbrough' 'Poole'
#  'Stockport' 'Wolverhampton' 'Eastbourne' 'Weston-super-Mare' 'London'
#  'Sheffield' 'Leeds' 'Raleigh' 'Cambridge' 'Kingston upon Hull'
#  'Milton Keynes' 'Nottingham' 'Woking' 'Birmingham' 'Basingstoke' 'Oxford'
#  'Luton' 'Manchester' 'Glasgow' 'Worthing' 'Darlington' 'Sunderland'
#  'Birkenhead' 'Chelmsford' 'Cardiff' 'Cheltenham' 'Portsmouth' 'Bath'
#  'Chester' 'Bradford' 'Coventry' 'Liverpool' 'Bournemouth' 'Dundee'
#  'County Down' 'Exeter' 'Derby' 'Swindon' 'Edinburgh' 'Hartlepool'
#  'Gateshead' 'Rochdale' 'Reading' 'Hemel Hempstead' 'Wakefield' 'Belfast'
#  'Worcester' 'Newport' 'Warrington' 'Sutton Coldfield' 'Solihull'
#  'Telford' 'Northampton' 'Sale' 'Chesterfield' 'Brighton' 'Stevenage'
#  'Leicester' 'Huddersfield' 'York' 'Newcastle upon Tyne' 'Preston'
#  'Gloucester' 'Southend-on-Sea' 'Swansea' 'Peterborough' 'Aberdeen'
#  'Watford' 'Gillingham' 'St Albans' 'Southampton' 'Maidstone' 'St Helens'
#  'High Wycombe' 'Blackpool' 'Slough' 'Grimsby' 'Ipswich' 'Stoke-on-Trent'
#  'Hastings' 'Crawley' 'Southport' 'Lincoln' 'Colchester' 'Barnsley'
#  'Salford' 'Rotherham' 'Bedford' 'Wigan' 'Doncaster' 'Bolton' 'Plymouth'
#  'Halifax' 'Norwich' 'Nuneaton']
# country: ['UK' 'France' 'Germany' 'USA' 'Portugal']
# age: [39 53 79 43 35 24 49 54 29 56 47 33 41 44 32 42 66 37 34 55 50 48 36 40
#  38 27 58 18 30 59 28 31 26 51 46 57 75 65 73 78 25 69 45 76 60 22 52 62
#  72 61 63 23 70 68 20 67 71 83 64 77 81 80 21 19 85 86 84 74 87 90 88 89
#  82 93 92 95]
# job: ['management' 'housemaid' 'retired' 'services' 'technician' 'student'
#  'blue-collar' 'self-employed' 'admin.' 'unemployed' 'entrepreneur'
#  'unknown']
# married: ['married' 'divorced' 'single']
# education: ['tertiary' 'primary' 'secondary' 'unknown']
# arrears: ['no' 'yes']
# current_balance: [ -1.9    3.62  27.87 ...  28.03  70.73 105.58]
# housing: ['no' 'yes']
# has_tv_package: ['yes' 'no' 'n']
# last_contact: ['unknown' 'cellular' 'telephone' 'cell']
# conn_tr: [4 1 3 2 5]
# last_contact_this_campaign_day: [11 28 13 27  9  4  5 19 29 14  7 25 12 20  6  2 15  8 30  3 21 18 23 22
#  16 17 31  1 26 10 24]
# last_contact_this_campaign_month: ['jun' 'jul' 'may' 'aug' 'sep' 'feb' 'nov' 'mar' 'jan' 'apr' 'dec' 'oct'
#  'j']
# this_campaign: [ 8  2  1 16  4  3  7 20 12  5 15  9 11  6 13 21 10 24 18 17 14 26 22 41
#  30 23 25 29 43 19 31 63 32 33 28 27 35 36 34 44 38 39 46 50 55 37 51 58]
# days_since_last_contact_previous_campaign: [ -1 377 362  99 392 150 337 357 167 164 182  93 121  95 188 365 186 101
#  238 805 183 189  89 412 103 251 100 415 344 370  98 174 190  86 321 503
#   28  91 181 160  90 227  42 404 172 318 179 381 123 398 334 477 276 345
#   94 440 349 113  92 360 305  84 363 295   9 264 425 129 111 168  70 191
#  242 196 315 772 184 156 239  56 175  82 579 120 199 274 430 273 282  74
#  128 355 119 420 124 105 325  79  60 389 301 331 223  69 197  14 328 203
#  347 266   1 322 298 204 353 192 194 171 138  62  97  87 234 106 324 352
#  200 312 435 368 281 332 291 307 202 117 342 178 187 236 112 166 350  75
#  253 486  34 176 258  22 359  96 320 180 297 371 148  88  20 384 323 271
#  257 136 414 356 270 391 154 170 369 300 346 213 313 293  38 135 555  13
#  246 126 378 210 169 104 290 152 409  80  83 140 461 449 326 107   6 366
#   85 394 551 294 401 195 134  55  21 339  44 211 364 343  48 330 256 304
#  458 386 279 260 198 265 491 299 115  77 207 252 173 185 272 217 280 842
#  269 250 367  73 351 717 216 520  65 341  43 701 561 162 426 278 385 139
#  329 854 228 541 338 144 159 161 132 259 335 336 314 518 372 285 267 125
#  163 214 470 130 116 225 193 147  66 108 102 558 475  58 462 481 296 348
#   61 358 466 143   2 177 133 302 490 153 149 261  63 122 268 262 310 209
#   81 316  41  68 587  64 460 235 286 155 244 436 127  29 469 247 137 395
#  450 651 287 792 201 232  53 141 427 114 375 478 771 231 208  17 245  71
#   76 229 288 275 254  57 782 165 308 774 317  35 648 495 327 283 361 439
#  421 306 311 205 479   4  50 284 255 110  52 455 388 529 474 303 233 146
#   31 131 109   8 354 776 778 289 145 586 340 804 749 403 521 263 157  15
#   37 212  78 407 374 444 118  36 544  40   5 319 594  67 397  33 277 309
#  222 442 626 241 237 553 433  10 828 603  72 424 333 457 417 504 532 376
#   24 142 595  59 616 683 158 535 476 728 437 769 826 390 373 243 399 515
#  206 387 761 405 459 292  27  49 422 230 472  12 221 463 550 151 784 690
#  446 445 428 224 240   7 871 419 411  45 248 432 557 526 249 410 808 542
#  215 465 670   3 379 220 380 226 452 489 485 434 791 592 219 383 779  51
#  431  26 760  46 745 687 493 393 585 667 218  19 655 456 536 454 500 530
#  413  47  39 508 547 524 484 492 578 514 480 467  54 756 396  32 464 633
#  531 511 382 416 656 589 562 528 775 850]
# contacted_during_previous_campaign: [  0   1   2   6   4   3   8  13   5  10  14   7  11  21   9  27  16  12
#   23  29  20  19  26  17  15  55  41  18  58  40  22  28  30  37  32 275
#   24  25  35  38  51]
# outcome_previous_campaign: ['unknown' 'success' 'other' 'failure']
# new_contract_this_campaign: ['yes' 'no']

# %% [markdown]
# From the unique values start analyzing important ones, town, country
# Correct the typos for last_contact, last_contact_this_campaign_month and housing

# %%
data.describe()
# Out:
#                  ID           age  current_balance       conn_tr  \
# count  5.066200e+04  50662.000000     50662.000000  50662.000000
# mean   5.502871e+07     40.979373        13.991210      3.005093
# std    2.598596e+07     10.919324        30.899163      1.409003
# min    1.000073e+07     18.000000       -80.190000      1.000000
# 25%    3.249964e+07     32.000000         0.820000      2.000000
# 50%    5.501127e+07     39.000000         4.720000      3.000000
# 75%    7.748809e+07     48.000000        14.950000      4.000000
# max    9.999952e+07     95.000000       984.170000      5.000000
#
#        last_contact_this_campaign_day  this_campaign  \
# count                    50662.000000   50662.000000
# mean                        15.768525       2.713217
# std                          8.347083       3.052227
# min                          1.000000       1.000000
# 25%                          8.000000       1.000000
# 50%                         16.000000       2.000000
# 75%                         21.000000       3.000000
# max                         31.000000      63.000000
#
#        days_since_last_contact_previous_campaign  \
# count                               50662.000000
# mean                                   42.644408
# std                                   102.238078
# min                                    -1.000000
# 25%                                    -1.000000
# 50%                                    -1.000000
# 75%                                    -1.000000
# max                                   871.000000
#
#        contacted_during_previous_campaign
# count                        50662.000000
# mean                             0.640283
# std                              2.358029
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              0.000000
# max                            275.000000

# %%
data['new_contract_this_campaign'].value_counts(normalize=True)
# Out:
# new_contract_this_campaign
# no     0.804607
# yes    0.195393
# Name: proportion, dtype: float64

# %% [markdown]
# Data is not balanced. Too many no to very few yes. To be handled with SMOTE or class_weights

# %%
data_old = data[data['contacted_during_previous_campaign']>20]
data_old.outcome_previous_campaign.value_counts()
# Out:
# outcome_previous_campaign
# other      35
# failure    26
# success     4
# Name: count, dtype: int64

# %% [markdown]
# Check if more contact is made for a success of previous outcome. It seems that is not the case.

# %%
data_new = data[data['this_campaign']>20]
data_new.new_contract_this_campaign.value_counts()
# Out:
# new_contract_this_campaign
# no     256
# yes      8
# Name: count, dtype: int64

# %% [markdown]
# Do the same with this_campaign. This also has no direct relationship and more calls have yielded no results

# %%
data['country'].value_counts()
# Out:
# country
# UK          50657
# France          2
# Germany         1
# USA             1
# Portugal        1
# Name: count, dtype: int64

# %% [markdown]
# Country can be ignored as this is home address and people live in UK and country has no direct relation to prediction and from below table it is clear that the town is still in UK which makes country column no use for our current analysis

# %%
data[data['country']!= 'UK']['town']
# Out:
# 632       Basildon
# 658       Aberdeen
# 747        Norwich
# 1338          Sale
# 6746    Birmingham
# Name: town, dtype: object

# %%
d_count = data.groupby("job")['new_contract_this_campaign'].value_counts().unstack(fill_value=0)
d_count['percentage'] = d_count['yes']/(d_count['yes']+d_count['no'])*100
d_count.sort_values(by='percentage')
# Out:
# new_contract_this_campaign    no   yes  percentage
# job
# blue-collar                 9133  1319   12.619594
# entrepreneur                1404   226   13.865031
# services                    3849   690   15.201586
# housemaid                   1130   207   15.482423
# technician                  6892  1572   18.572779
# self-employed               1439   335   18.883878
# unknown                      266    63   19.148936
# admin.                      4688  1177   20.068201
# management                  8385  2464   22.711771
# unemployed                  1121   380   25.316456
# retired                     1783   961   35.021866
# student                      673   505   42.869270

# %% [markdown]
# The %age of yes and no varies huge and this cannot be dropped and can be a driving force for the prediction. So keep the job column

# %%
d_count = data.groupby("married")['new_contract_this_campaign'].value_counts().unstack(fill_value=0)
d_count['percentage'] = d_count['yes']/(d_count['yes']+d_count['no'])*100
d_count.sort_values(by='percentage')
# Out:
# new_contract_this_campaign     no   yes  percentage
# married
# married                     24889  5156   17.160925
# divorced                     4690  1159   19.815353
# single                      11184  3584   24.268689

# %% [markdown]
# The variation for married column is very small and hence can be dropped

# %%
d_count = data.groupby("conn_tr")['new_contract_this_campaign'].value_counts().unstack(fill_value=0)
d_count['percentage'] = d_count['yes']/(d_count['yes']+d_count['no'])*100
d_count.sort_values(by='percentage')
# Out:
# new_contract_this_campaign    no   yes  percentage
# conn_tr
# 3                           8259  1921   18.870334
# 5                           8121  1964   19.474467
# 2                           8217  2017   19.708814
# 4                           8194  2022   19.792482
# 1                           7972  1975   19.855233

# %% [markdown]
# The variation for conn_tr column is very small and hence can be dropped. Also, there is no specific role for this conn_tr which by itself or with other features showing driving force. From belo cell, it is clear that it is not even number of connections per household. Hence drop this column

# %%
d_count = data.groupby("married")['conn_tr'].value_counts().unstack(fill_value=0)
d_count
# Out:
# conn_tr      1     2     3     4     5
# married
# divorced  1105  1219  1160  1182  1183
# married   5899  6071  6079  6075  5921
# single    2943  2944  2941  2959  2981

# %%
d_count = data.groupby("town")['new_contract_this_campaign'].value_counts().unstack(fill_value=0)
d_count['percentage'] = d_count['yes']/(d_count['yes']+d_count['no'])*100

# %%
pd.set_option('display.max_rows', 500)
d_count.sort_values(by='percentage')
# Out:
# new_contract_this_campaign    no  yes  percentage
# town
# Colchester                   368   63   14.617169
# Wakefield                    327   57   14.843750
# Kingston upon Hull           357   65   15.402844
# Southend-on-Sea              316   59   15.733333
# Newcastle upon Tyne          319   61   16.052632
# Birkenhead                   330   64   16.243655
# Derby                        319   62   16.272966
# Huddersfield                 328   64   16.326531
# Hastings                     327   65   16.581633
# Belfast                      336   68   16.831683
# Peterborough                 325   66   16.879795
# Luton                        315   65   17.105263
# Woking                       334   69   17.121588
# Sale                         314   65   17.150396
# Blackburn                    309   64   17.158177
# Gloucester                   334   70   17.326733
# Nuneaton                     352   74   17.370892
# Oxford                       326   69   17.468354
# Dundee                       357   76   17.551963
# Salford                      320   69   17.737789
# Rotherham                    333   72   17.777778
# Crawley                      335   73   17.892157
# Blackpool                    312   68   17.894737
# Bath                         320   70   17.948718
# Wolverhampton                324   71   17.974684
# Bedford                      301   66   17.983651
# Gillingham                   325   72   18.136020
# Brighton                     319   71   18.205128
# Liverpool                   1301  290   18.227530
# Halifax                      323   72   18.227848
# York                         323   73   18.434343
# Warrington                   322   73   18.481013
# Slough                       313   71   18.489583
# Aberdeen                     312   71   18.537859
# Wigan                        316   72   18.556701
# Maidstone                    368   84   18.584071
# Stevenage                    293   67   18.611111
# Weston-super-Mare            322   74   18.686869
# Hartlepool                   321   74   18.734177
# Darlington                   379   88   18.843683
# Watford                      323   75   18.844221
# Edinburgh                    341   80   19.002375
# Sheffield                    334   79   19.128329
# Raleigh                      349   83   19.212963
# Milton Keynes                340   81   19.239905
# Exeter                       344   82   19.248826
# Barnsley                     323   77   19.250000
# Glasgow                     1606  385   19.337017
# Chesterfield                 308   74   19.371728
# Cardiff                      349   84   19.399538
# Basingstoke                  377   91   19.444444
# Portsmouth                   318   77   19.493671
# Worthing                     326   79   19.506173
# London                      2608  633   19.531009
# Grimsby                      337   82   19.570406
# County Down                  353   86   19.589977
# Nottingham                   316   77   19.592875
# Manchester                  1000  244   19.614148
# Norwich                      310   76   19.689119
# Bradford                     322   79   19.700748
# Birmingham                  1907  476   19.974822
# St Helens                    331   83   20.048309
# Southampton                  346   87   20.092379
# Chelmsford                   312   79   20.204604
# Rochdale                     338   86   20.283019
# Leicester                    334   85   20.286396
# Bristol                     1349  344   20.318960
# Eastbourne                   336   86   20.379147
# Plymouth                     328   84   20.388350
# Reading                      314   81   20.506329
# Newport                      337   87   20.518868
# Bournemouth                  336   87   20.567376
# Worcester                    323   84   20.638821
# Doncaster                    337   89   20.892019
# Lincoln                      313   83   20.959596
# Sunderland                   320   85   20.987654
# Cambridge                    323   86   21.026895
# Stockport                    340   91   21.113689
# Poole                        309   83   21.173469
# High Wycombe                 306   83   21.336761
# Coventry                     332   91   21.513002
# Northampton                  341   94   21.609195
# Swindon                      339   94   21.709007
# Swansea                      299   83   21.727749
# Sutton Coldfield             333   93   21.830986
# Middlesbrough                331   93   21.933962
# Chester                      330   93   21.985816
# Southport                    290   82   22.043011
# Leeds                        315   90   22.222222
# Gateshead                    317   91   22.303922
# Stoke-on-Trent               308   89   22.418136
# Bolton                       330   96   22.535211
# Hemel Hempstead              308   90   22.613065
# Telford                      319   94   22.760291
# Ipswich                      332   98   22.790698
# Oldham                       302   91   23.155216
# Cheltenham                   298   91   23.393316
# Basildon                     312   96   23.529412
# Solihull                     324  100   23.584906
# Preston                      313   98   23.844282
# St Albans                    292   92   23.958333

# %% [markdown]
# From above it is very clear that town has similar ratio of convertion and hence can be dropped too

# %%
data['current_balance'].hist()
# Out:
# <Axes: >

# %%
ax = data['age'].hist() 
ax.set_xlabel('Age')
ax.set_ylabel('Frequency')
ax.set_title('Distribution of Age')
plt.show()

# %%
data.groupby('new_contract_this_campaign')['current_balance'].mean()
# Out:
# new_contract_this_campaign
# 0    13.016576
# 1    18.004650
# Name: current_balance, dtype: float64

# %%
data['new_contract_this_campaign'] = data['new_contract_this_campaign'].map({'yes':1, 'no':0}).astype(int)

# %%
data.corr(numeric_only=True)
# Out:
#                                                  ID       age  \
# ID                                         1.000000 -0.001237
# age                                       -0.001237  1.000000
# current_balance                           -0.004142  0.101688
# conn_tr                                    0.008362 -0.005501
# last_contact_this_campaign_day             0.000980 -0.007633
# this_campaign                             -0.005354  0.001733
# days_since_last_contact_previous_campaign -0.002558 -0.017208
# contacted_during_previous_campaign        -0.000492  0.005704
# new_contract_this_campaign                -0.003082  0.030501
#
#                                            current_balance   conn_tr  \
# ID                                               -0.004142  0.008362
# age                                               0.101688 -0.005501
# current_balance                                   1.000000 -0.001223
# conn_tr                                          -0.001223  1.000000
# last_contact_this_campaign_day                    0.007047  0.004237
# this_campaign                                    -0.014508  0.003277
# days_since_last_contact_previous_campaign         0.007244 -0.005558
# contacted_during_previous_campaign                0.019504 -0.000411
# new_contract_this_campaign                        0.064008 -0.002382
#
#                                            last_contact_this_campaign_day  \
# ID                                                               0.000980
# age                                                             -0.007633
# current_balance                                                  0.007047
# conn_tr                                                          0.004237
# last_contact_this_campaign_day                                   1.000000
# this_campaign                                                    0.156636
# days_since_last_contact_previous_campaign                       -0.089422
# contacted_during_previous_campaign                              -0.053263
# new_contract_this_campaign                                      -0.038615
#
#                                            this_campaign  \
# ID                                             -0.005354
# age                                             0.001733
# current_balance                                -0.014508
# conn_tr                                         0.003277
# last_contact_this_campaign_day                  0.156636
# this_campaign                                   1.000000
# days_since_last_contact_previous_campaign      -0.093053
# contacted_during_previous_campaign             -0.037818
# new_contract_this_campaign                     -0.091829
#
#                                            days_since_last_contact_previous_campaign  \
# ID                                                                         -0.002558
# age                                                                        -0.017208
# current_balance                                                             0.007244
# conn_tr                                                                    -0.005558
# last_contact_this_campaign_day                                             -0.089422
# this_campaign                                                              -0.093053
# days_since_last_contact_previous_campaign                                   1.000000
# contacted_during_previous_campaign                                          0.460869
# new_contract_this_campaign                                                  0.126678
#
#                                            contacted_during_previous_campaign  \
# ID                                                                  -0.000492
# age                                                                  0.005704
# current_balance                                                      0.019504
# conn_tr                                                             -0.000411
# last_contact_this_campaign_day                                      -0.053263
# this_campaign                                                       -0.037818
# days_since_last_contact_previous_campaign                            0.460869
# contacted_during_previous_campaign                                   1.000000
# new_contract_this_campaign                                           0.112417
#
#                                            new_contract_this_campaign
# ID                                                          -0.003082
# age                                                          0.030501
# current_balance                                              0.064008
# conn_tr                                                     -0.002382
# last_contact_this_campaign_day                              -0.038615
# this_campaign                                               -0.091829
# days_since_last_contact_previous_campaign                    0.126678
# contacted_during_previous_campaign                           0.112417
# new_contract_this_campaign                                   1.000000

# %% [markdown]
# The biggest correlation is age, current_balance, days_since_last_contact_precious_campaign, contacted_during_previous_campaign, this_campaign

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(data.corr(numeric_only=True), annot=False)
plt.show()
